# %% [markdown]
# # Example: REV analysis for PD
#
# This example demonstrates how to perform REV analysis for persistence diagrams (PD), generated by PD-generator.
#
# PD is a set of "birth"-"death" persistence pairs located at $XY$ coordinate plane. (TO DO: describe PD more here).
#
# Using our library, one can perform REV analysis for PD$_0$, PD$_1$ and PD$_2$ - persistence diagrams of rank 0, 1 and 3, respectively. Four different vectorization methods, mapping 2D PD structure into 1D vector, are available: simple binnig, persistence image, landscape and silhouette.
#
# Here, we present REV analysis of PD with PD0 metric and simple binnig vectorization method.

# %%
from julia.api import Julia
jl = Julia(compiled_modules=False)
from revanalyzer import REVAnalyzer
from revanalyzer.generators import generate_PD
from revanalyzer.metrics import PD0
from revanalyzer.vectorizers import SimpleBinningVectorizer

# %% [markdown]
# PD for subcuts are generated using the external application. So, instead of using generate() method from REVAnalyzer class, one needs to run generator function generate_PD. This function computes birth-death pairs for each subcube, given by parameters 'cut_step' and 'sREV_max_size'. The results are saved in the same way as for the metrics generated inside REVAnalizer library.

# %%
#input data for generator function

image = 'ceramic300' #binary file of 'uint8' type representing 3D image.
size = 300 #image linear size. Note, that only cubical images can be analyzed. 
cut_step = 50 # increment step of subcube size
sREV_max_size = 200 #maximal subcube size for which sREV analysis is performed.
inputdir = 'data' # path to folder containing image, default: 'data'
outputdir = 'output' # path to outputfolder containig image, default: 'output'
exe_path = '/home/azubov/pd_generator/pore-network-extraction/build/bin/persistence_pairs' #path to PNM-exractor exe file
n_threads = 48 #number of CPU cores used by PNM-extractor, default: 1
p_limit = 0 #persistence limit parameter; default: 0, to consider all birth-death pairs.
show_time = True #default: False. Added to monitor time cost for large images.

# %%
generate_PD(image, size, cut_step, sREV_max_size, exe_path, n_threads, p_limit, inputdir, 
            outputdir,  show_time = True)
# Out:
# Size  300 , run time:
# --- 33.05346941947937 seconds ---
# Size  50 , run time:
# --- 1.8835060596466064 seconds ---
# Size  100 , run time:
# --- 9.691327571868896 seconds ---
# Size  150 , run time:
# --- 33.42217206954956 seconds ---
# Size  200 , run time:
# --- 84.01402163505554 seconds ---
# Size  250 , run time:
# --- 18.39647674560547 seconds ---

# %%
#initizialization

bins = 20 #number of bins at each axe in XY plane.
skip_zeros = True # If True, bins of 2D histogram empty for both compared PDs are not included into the final vectors;
                  #default: True.
norm = 2  #Norm of vectors used in REV analysis. The same, as parameter 'ord' in numpy.linalg.norm function; 
          #default: 2.

vectorizer = SimpleBinningVectorizer(bins) #vectorizer inizialization

metric = PD0(vectorizer) #metric inizialization

analyzer = REVAnalyzer(metric, image, size, cut_step, sREV_max_size)

# %%
#read the metric values for the specific subcube:
cut_size = 150
cut_id = 5
value = analyzer.read(cut_size, cut_id)
print(value)
# Out:
# [[-10.1504    -2.82895 ]
#  [ -9.49242   -3.63874 ]
#  [ -9.49237   -8.92277 ]
#  ...
#  [ -0.500725  -0.500725]
#  [ -0.500272   3.97214 ]
#  [ -0.500091   1.5     ]]

# %%
#Visualize PD for a given subcube:
analyzer.show(cut_size, cut_id)

# %%
#vectorization
analyzer.vectorize()

# %%
#fix thresholds and analyze vectorized data
dREV_threshold = 0.2
sREV_threshold = 0.2
analyzer.analyze(dREV_threshold, sREV_threshold)

# %%
print(analyzer.metric_mean)
print(analyzer.metric_std)
print(analyzer.metric_normed_std_1)
print(analyzer.metric_normed_std_2)
# Out:
# {100: 0.4335881894738049, 150: 0.16515155530322256, 200: 0.08963866365099481, 250: 0.042565255980750526, 300: 0.019457986556533538}
# {100: 0.11989468765794196, 150: 0.05834312099506982, 200: 0.03855647404170247, 250: 0.009156894993867527}
# {100: 0.5994734382897098, 150: 0.2917156049753491, 200: 0.19278237020851233, 250: 0.04578447496933763}
# {100: 0.2765174203740284, 150: 0.2917156049753491, 200: 0.19278237020851233, 250: 0.04578447496933763}

# %%
#get dREV and sREV size estimation
print(analyzer.dREV_size_1)
print(analyzer.sREV_size_1)
print(analyzer.sREV_size_2)
# Out:
# 150
# 200
# 200

# %%
analyzer.show_results()
